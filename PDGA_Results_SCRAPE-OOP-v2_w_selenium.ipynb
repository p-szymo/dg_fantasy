# %% [markdown]
# # PDGA Results
#
# ## *<u>Documentation</u>*
#
# [Authorization](https://www.pdga.com/dev/api/rest/v1/auth)
#
# [API call examples](https://www.pdga.com/dev/api/rest/v1/services)
#
# > **Note**: The PDGA Developer Program is currently closed. We are not accepting new applications for the PDGA Developer Program at this time. We do anticipate opening up the program again in the future once development of an updated version of the API is complete.
#
#
# ## *<u>Import functions</u>*

# %%
from functions import *
# import requests
# from bs4 import BeautifulSoup as bs
# import pandas as pd
# import itertools
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import itertools
import time

# %load_ext autoreload
# %autoreload 2

# %%
players_links = players_links_list()
players_links[:5]
# Out:
# ['https://www.pdga.com/player/75412',
#  'https://www.pdga.com/player/45971',
#  'https://www.pdga.com/player/50670',
#  'https://www.pdga.com/player/38008',
#  'https://www.pdga.com/player/8332']

# %%
players = []
errors = []

for link in players_links:
    try:
        players.append(Player(url=link))
    except:
        print(link)
        errors.append(link)
    time.sleep(1)

# %%
len(players)
# Out:
# 118

# %%
errors
# Out:
# []

# %%
soup = soupify('https://www.pdga.com/tour/event/72916')
table = soup.select('table.results#tournament-stats-3')[0]

# %%
odd_rows = table.select('tr[class*="odd"]')
even_rows = table.select('tr[class*="even"]')

# %%
odd_rows[0]
# Out:
# <tr class="odd"><td class="place" rowspan="1">1</td><td class="player"><a class="tooltip" data-tooltip-content="#player-details-69178" href="/player/69178">Trevor Darragh</a></td><td class="pdga-number">69178</td><td class="player-rating propagator" title="propagator">962</td><td class="par under" data-text="-1" rowspan="1">-1</td><td class="round" rowspan="1"><a class="score" href="/tour/live?eventId=72916&amp;round=1&amp;division=MA1" title="View hole scores">61</a></td><td class="round-rating" rowspan="1">996</td><td class="round" rowspan="1"></td><td class="round-rating" rowspan="1"></td><td class="round" rowspan="1"></td><td class="round-rating" rowspan="1"></td><td class="total" rowspan="1">61</td> </tr>

# %%
len(even_rows)
# Out:
# 31

# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib import request

def soupify_2(url):
    page = request.Request(url)
    soup = bs(page) #, "html.parser"
    return soup

# %%
page = request.Request(url)
page

# %%
page.__dict__
# Out:
# {'_full_url': 'https://www.pdga.com/apps/tournament/live/event?eventId=72916&division=MA1&view=Scores&round=1',
#  'fragment': None,
#  'type': 'https',
#  'host': 'www.pdga.com',
#  'selector': '/apps/tournament/live/event?eventId=72916&division=MA1&view=Scores&round=1',
#  'headers': {},
#  'unredirected_hdrs': {},
#  '_data': None,
#  '_tunnel_host': None,
#  'origin_req_host': 'www.pdga.com',
#  'unverifiable': False}

# %%
def soupify(url):
    page = requests.get(url)
    soup = bs(page.content, "html.parser")
    return soup

# %%
url = 'https://www.pdga.com/apps/tournament/live/js/chunk-2d0a3962.01f995e9.js'

# %%
soupify(url)
# Out:
# (window["webpackJsonp"]=window["webpackJsonp"]||[]).push([["chunk-2d0a3962"],{"038a":function(t,e,l){"use strict";l.r(e);var n=function(){var t=this,e=t.$createElement,l=t._self._c||e;return l("svg",{attrs:{width:t.width,height:t.height,viewBox:"0 0 16 16",fill:"none",xmlns:"http://www.w3.org/2000/svg"}},[l("path",{attrs:{"fill-rule":"evenodd","clip-rule":"evenodd",d:"M3.75736 10.2426L7.51472 14H5C4.44772 14 4 14.4477 4 15C4 15.5523 4.44772 16 5 16H11C11.5523 16 12 15.5523 12 15C12 14.4477 11.5523 14 11 14H8.48528L12.2426 10.2426C14.5858 7.89949 14.5858 4.1005 12.2426 1.75736C9.89949 -0.585786 6.1005 -0.585786 3.75736 1.75736C1.41421 4.1005 1.41421 7.89949 3.75736 10.2426ZM8 8C9.10457 8 10 7.10457 10 6C10 4.89543 9.10457 4 8 4C6.89543 4 6 4.89543 6 6C6 7.10457 6.89543 8 8 8Z",fill:t.color}})])},i=[],r={name:"LocationNear",props:{height:{type:String,default:"16"},width:{type:String,default:"16"},color:{type:String,default:"#1A1A1A"}}},o=r,a=l("2877"),d=Object(a["a"])(o,n,i,!1,null,nul
# ...

# %%
<div data-v-28d8b9ee="" class="round-scores-container"><div class="outer-wrapper scores-full-table"><div class="b-overlay-wrap position-relative"><div class="pdga-table" style="border-radius: 10px; background-color: transparent;"><!----><div class="header-row" style="top: 61px; background-color: rgb(255, 255, 255);"><div class=" header-col header-col-sticky col-shadow" style="cursor: pointer; flex-basis: 38px; min-width: 38px;"><div class="header-cell-wrapper"><div style="display: flex; flex-direction: column; width: 100%; align-items: center;"><div style="display: flex; width: 100%; justify-content: center;"><!----><div class="generic-header"> # </div></div></div></div></div><div class=" header-col header-col-sticky col-shadow" style="cursor: pointer; flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="header-cell-wrapper"><div style="display: flex; flex-direction: column; width: 100%; align-items: center;"><div style="display: flex; width: 100%; justify-content: center;"><!----><div class="generic-header player-header"> Player </div></div></div></div></div><div class=" header-col" style="cursor: pointer; flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class="header-cell-wrapper"><div style="display: flex; flex-direction: column; width: 100%; align-items: center;"><div style="display: flex; width: 100%; justify-content: center;"><!----><div class="generic-header"> Rd </div></div></div></div></div><div class=" header-col" style="cursor: pointer; flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="header-cell-wrapper"><div style="display: flex; flex-direction: column; width: 100%; align-items: center;"><div style="display: flex; width: 100%; justify-content: center;"><!----><div class="generic-header"> Thru </div></div></div></div></div><div class=" header-col" style="cursor: pointer; flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div class="header-cell-wrapper"><div style="display: flex; flex-direction: column; width: 100%; align-items: center;"><div style="display: flex; width: 100%; justify-content: center;"><!----><div class="hole-header"> 1 </div></div><div class="hole-header-wrapper"><div class="hole-length"> 617 </div><div class="hole-par"> 4 </div></div></div></div></div><div class=" header-col" style="cursor: pointer; flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div class="header-cell-wrapper"><div style="display: flex; flex-direction: column; width: 100%; align-items: center;"><div style="display: flex; width: 100%; justify-content: center;"><!----><div class="hole-header"> 2 </div></div><div class="hole-header-wrapper"><div class="hole-length"> 268 </div><div class="hole-par"> 3 </div></div></div></div></div><div class=" header-col" style="cursor: pointer; flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div class="header-cell-wrapper"><div style="display: flex; flex-direction: column; width: 100%; align-items: center;"><div style="display: flex; width: 100%; justify-content: center;"><!----><div class="hole-header"> 3 </div></div><div class="hole-header-wrapper"><div class="hole-length"> 328 </div><div class="hole-par"> 4 </div></div></div></div></div><div class=" header-col" style="cursor: pointer; flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div class="header-cell-wrapper"><div style="display: flex; flex-direction: column; width: 100%; align-items: center;"><div style="display: flex; width: 100%; justify-content: center;"><!----><div class="hole-header"> 4 </div></div><div class="hole-header-wrapper"><div class="hole-length"> 245 </div><div class="hole-par"> 3 </div></div></div></div></div><div class=" header-col" style="cursor: pointer; flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div class="header-cell-wrapper"><div style="display: flex; flex-direction: column; width: 100%; align-items: center;"><div style="display: flex; width: 100%; justify-content: center;"><!----><div class="hole-header"> 5 </div></div><div class="hole-header-wrapper"><div class="hole-length"> 396 </div><div class="hole-par"> 3 </div></div></div></div></div><div class=" header-col" style="cursor: pointer; flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div class="header-cell-wrapper"><div style="display: flex; flex-direction: column; width: 100%; align-items: center;"><div style="display: flex; width: 100%; justify-content: center;"><!----><div class="hole-header"> 6 </div></div><div class="hole-header-wrapper"><div class="hole-length"> 289 </div><div class="hole-par"> 3 </div></div></div></div></div><div class=" header-col" style="cursor: pointer; flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div class="header-cell-wrapper"><div style="display: flex; flex-direction: column; width: 100%; align-items: center;"><div style="display: flex; width: 100%; justify-content: center;"><!----><div class="hole-header"> 7 </div></div><div class="hole-header-wrapper"><div class="hole-length"> 254 </div><div class="hole-par"> 3 </div></div></div></div></div><div class=" header-col" style="cursor: pointer; flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div class="header-cell-wrapper"><div style="display: flex; flex-direction: column; width: 100%; align-items: center;"><div style="display: flex; width: 100%; justify-content: center;"><!----><div class="hole-header"> 8 </div></div><div class="hole-header-wrapper"><div class="hole-length"> 621 </div><div class="hole-par"> 4 </div></div></div></div></div><div class=" header-col" style="cursor: pointer; flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div class="header-cell-wrapper"><div style="display: flex; flex-direction: column; width: 100%; align-items: center;"><div style="display: flex; width: 100%; justify-content: center;"><!----><div class="hole-header"> 9 </div></div><div class="hole-header-wrapper"><div class="hole-length"> 546 </div><div class="hole-par"> 4 </div></div></div></div></div><div class=" header-col" style="cursor: pointer; flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div class="header-cell-wrapper"><div style="display: flex; flex-direction: column; width: 100%; align-items: center;"><div style="display: flex; width: 100%; justify-content: center;"><!----><div class="hole-header"> 10 </div></div><div class="hole-header-wrapper"><div class="hole-length"> 262 </div><div class="hole-par"> 3 </div></div></div></div></div><div class=" header-col" style="cursor: pointer; flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div class="header-cell-wrapper"><div style="display: flex; flex-direction: column; width: 100%; align-items: center;"><div style="display: flex; width: 100%; justify-content: center;"><!----><div class="hole-header"> 11 </div></div><div class="hole-header-wrapper"><div class="hole-length"> 647 </div><div class="hole-par"> 4 </div></div></div></div></div><div class=" header-col" style="cursor: pointer; flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div class="header-cell-wrapper"><div style="display: flex; flex-direction: column; width: 100%; align-items: center;"><div style="display: flex; width: 100%; justify-content: center;"><!----><div class="hole-header"> 12 </div></div><div class="hole-header-wrapper"><div class="hole-length"> 441 </div><div class="hole-par"> 4 </div></div></div></div></div><div class=" header-col" style="cursor: pointer; flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div class="header-cell-wrapper"><div style="display: flex; flex-direction: column; width: 100%; align-items: center;"><div style="display: flex; width: 100%; justify-content: center;"><!----><div class="hole-header"> 13 </div></div><div class="hole-header-wrapper"><div class="hole-length"> 451 </div><div class="hole-par"> 3 </div></div></div></div></div><div class=" header-col" style="cursor: pointer; flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div class="header-cell-wrapper"><div style="display: flex; flex-direction: column; width: 100%; align-items: center;"><div style="display: flex; width: 100%; justify-content: center;"><!----><div class="hole-header"> 14 </div></div><div class="hole-header-wrapper"><div class="hole-length"> 331 </div><div class="hole-par"> 3 </div></div></div></div></div><div class=" header-col" style="cursor: pointer; flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div class="header-cell-wrapper"><div style="display: flex; flex-direction: column; width: 100%; align-items: center;"><div style="display: flex; width: 100%; justify-content: center;"><!----><div class="hole-header"> 15 </div></div><div class="hole-header-wrapper"><div class="hole-length"> 545 </div><div class="hole-par"> 4 </div></div></div></div></div><div class=" header-col" style="cursor: pointer; flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div class="header-cell-wrapper"><div style="display: flex; flex-direction: column; width: 100%; align-items: center;"><div style="display: flex; width: 100%; justify-content: center;"><!----><div class="hole-header"> 16 </div></div><div class="hole-header-wrapper"><div class="hole-length"> 324 </div><div class="hole-par"> 3 </div></div></div></div></div><div class=" header-col" style="cursor: pointer; flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div class="header-cell-wrapper"><div style="display: flex; flex-direction: column; width: 100%; align-items: center;"><div style="display: flex; width: 100%; justify-content: center;"><!----><div class="hole-header"> 17 </div></div><div class="hole-header-wrapper"><div class="hole-length"> 303 </div><div class="hole-par"> 3 </div></div></div></div></div><div class=" header-col" style="cursor: pointer; flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div class="header-cell-wrapper"><div style="display: flex; flex-direction: column; width: 100%; align-items: center;"><div style="display: flex; width: 100%; justify-content: center;"><!----><div class="hole-header"> 18 </div></div><div class="hole-header-wrapper"><div class="hole-length"> 648 </div><div class="hole-par"> 4 </div></div></div></div></div><div class=" header-col" style="cursor: pointer; flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class="header-cell-wrapper"><div style="display: flex; flex-direction: column; width: 100%; align-items: center;"><div style="display: flex; width: 100%; justify-content: center;"><!----><div class="hole-header"><div> Tot </div></div></div><div class="hole-header-wrapper"><div class="hole-length"> 7516 </div><div class="hole-par"> 62 </div></div></div></div></div></div><div class="table-body" style=""><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> 1 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><span class="image-container image-container-40px podium-avatar"><img src="/files/styles/large/public/pictures/picture-148266-1599834030.jpg"></span><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Trevor </span><span class="player-last-name"> Darragh </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> -1 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 61 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> 2 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><span class="image-container image-container-40px podium-avatar"><img src="/files/styles/large/public/pictures/picture-2509976-1667761344.jpg"></span><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Eddie </span><span class="player-last-name"> Van Eaton </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> E </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 62 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> 3 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><span class="image-container image-container-40px podium-avatar"><img src="/apps/tournament/live/img/PDGA_Player_Photo_Default.b95a53af.svg"></span><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Adam </span><span class="player-last-name"> Prah </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +1 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 63 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T4 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Luke </span><span class="player-last-name"> Milhoan </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +3 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 65 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T4 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Judah </span><span class="player-last-name"> Kooistra </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +3 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 65 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T4 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Malachi </span><span class="player-last-name"> Bontrager </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +3 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 65 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T4 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Roger </span><span class="player-last-name"> Boone Jr </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +3 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 65 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T4 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Ian </span><span class="player-last-name"> Rankin </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +3 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 65 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> 9 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Kyle </span><span class="player-last-name"> Somers </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +4 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 66 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T10 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Jackson </span><span class="player-last-name"> Lozier </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +5 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 67 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T10 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Sean </span><span class="player-last-name"> Chi </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +5 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 7 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 67 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T10 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Paul </span><span class="player-last-name"> Bailey </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +5 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 67 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T10 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Nick </span><span class="player-last-name"> Murphy </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +5 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 67 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T10 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Caleb </span><span class="player-last-name"> Ward </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +5 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 67 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T10 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Richard </span><span class="player-last-name"> Tredinnick </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +5 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 67 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T10 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Joshua </span><span class="player-last-name"> Szymanowski </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +5 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 67 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T17 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Joseph </span><span class="player-last-name"> Seitz </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +6 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 68 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T17 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Andrew </span><span class="player-last-name"> Coxe </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +6 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 7 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 68 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T17 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Nick </span><span class="player-last-name"> Piccillo </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +6 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 68 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T17 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> John </span><span class="player-last-name"> Bernard </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +6 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 68 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T17 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Greyson </span><span class="player-last-name"> Lifto </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +6 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 68 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T17 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Jonathan </span><span class="player-last-name"> Price </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +6 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 68 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T17 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Justin </span><span class="player-last-name"> Matherly </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +6 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 68 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T24 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Jake </span><span class="player-last-name"> Kelly </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +7 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 69 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T24 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Derek </span><span class="player-last-name"> Jones </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +7 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 69 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T24 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Evan </span><span class="player-last-name"> Riley </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +7 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 69 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T24 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Jackson </span><span class="player-last-name"> Hook </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +7 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 69 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T28 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Hunter </span><span class="player-last-name"> Roark </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +8 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 70 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T28 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Zander </span><span class="player-last-name"> Weber </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +8 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 7 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 70 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T28 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Michael </span><span class="player-last-name"> Karp </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +8 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 7 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 70 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T28 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Preston </span><span class="player-last-name"> Farley </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +8 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 70 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T32 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Travis </span><span class="player-last-name"> Carter </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +9 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-4"> 8 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 71 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T32 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Travis </span><span class="player-last-name"> Page III </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +9 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 71 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T32 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Owen </span><span class="player-last-name"> Stewart </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +9 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 7 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 71 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T32 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Conlan </span><span class="player-last-name"> Fletcher </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +9 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 71 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T32 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> William </span><span class="player-last-name"> Hathaway </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +9 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 71 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T32 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Joel </span><span class="player-last-name"> Murray </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +9 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 71 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T32 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Zachary </span><span class="player-last-name"> Taylor </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +9 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 71 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T32 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Ethan </span><span class="player-last-name"> Burgin </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +9 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 7 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 71 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T32 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Todd </span><span class="player-last-name"> Doremus </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +9 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 71 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T41 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Steven </span><span class="player-last-name"> Ritchey </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +10 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 72 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T41 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Michael </span><span class="player-last-name"> Sevachko </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +10 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 7 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 72 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T41 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Addison </span><span class="player-last-name"> Sells </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +10 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 72 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T41 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Zachary </span><span class="player-last-name"> Nelson </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +10 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 72 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T41 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Daniel </span><span class="player-last-name"> Hicks </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +10 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 72 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T46 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Benuel </span><span class="player-last-name"> Hostetter </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +11 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 7 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 73 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T46 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Ryan </span><span class="player-last-name"> Smith </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +11 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 73 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T46 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Matt </span><span class="player-last-name"> Howes </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +11 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 73 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T46 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Asher </span><span class="player-last-name"> Beaudin </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +11 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 73 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T50 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Scott </span><span class="player-last-name"> Wallace </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +12 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 74 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T50 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> David </span><span class="player-last-name"> Huie </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +12 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 74 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T50 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Ben </span><span class="player-last-name"> Adinolfi </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +12 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-5"> 8 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 74 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T50 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Douglas </span><span class="player-last-name"> Gregory </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +12 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 74 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T50 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Brett </span><span class="player-last-name"> Basher </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +12 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 74 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T50 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Jacob </span><span class="player-last-name"> Ingram </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +12 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 7 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 74 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> 56 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> John </span><span class="player-last-name"> Weathersby </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +14 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 7 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-4"> 7 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 76 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T57 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Cody </span><span class="player-last-name"> Scott </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +15 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-5"> 8 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 77 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> T57 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Jacob </span><span class="player-last-name"> Dell </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +15 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-4"> 7 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 7 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 7 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 77 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> 59 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Jackson </span><span class="player-last-name"> Klingenberg </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +16 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-5"> 8 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 78 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> 60 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Noah </span><span class="player-last-name"> Tucich </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +17 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-4"> 8 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 79 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> 61 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Taylor </span><span class="player-last-name"> Blackford </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +18 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 7 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs--1"> 2 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 80 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> 62 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Chris </span><span class="player-last-name"> Rowland </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +19 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 7 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 81 </div></div></div><!----></div><!----></div><div class="table-row" style="min-width: 845px;"><div class="b-overlay-wrap position-relative row-overlay"><div class="row-fields-wrapper" style="cursor: pointer;"><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 38px; min-width: 38px;"><div class="position-cell"> 63 </div></div><div class="cell-wrapper sticky-cell col-shadow" style="flex-basis: 180px; flex-grow: 2; min-width: 180px; left: 38px;"><div class="player-cell-wrapper"><!----><div class="player-cell"><!----><div class="player-full-name"><span class="player-first-name"> Alex The Doubler </span><span class="player-last-name"> Nackley </span></div></div></div></div><div class="cell-wrapper" style="flex-basis: 52px; flex-grow: 1; min-width: 52px;"><div class=""> +30 </div></div><div class="cell-wrapper" style="flex-basis: 37px; flex-grow: 1; min-width: 37px;"><div class="thru-finished"> F </div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-4"> 7 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 7 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-4"> 7 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 7 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 5 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-2"> 6 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-1"> 4 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-3"> 7 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-0"> 3 </div></div></div><div class="cell-wrapper" style="flex-basis: 28px; flex-grow: 1; min-width: 28px;"><div><div class="hole-cell hs hs-5"> 9 </div></div></div><div class="cell-wrapper" style="flex-basis: 34px; flex-grow: 1; min-width: 34px;"><div class=""> 92 </div></div></div><!----></div><!----></div></div></div><!----></div></div></div>

# %%
url = 'https://www.pdga.com/apps/tournament/live/event?eventId=72916&division=MA1&view=Scores&round=1'

# %%
import sys
print(sys.path)
# Out:
# ['/opt/anaconda3/envs/learn-env/lib/python36.zip', '/opt/anaconda3/envs/learn-env/lib/python3.6', '/opt/anaconda3/envs/learn-env/lib/python3.6/lib-dynload', '', '/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages', '/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/locket-0.2.1-py3.6.egg', '/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/extensions', '/Users/p.szymo/.ipython']

# %%
sys.__dict__
# Out:
# {'__name__': 'sys',
# ...

# %%
e = Event('battle for bedford')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-98-846dd9f4fbec> in <module>
# ----> 1 e = Event('battle for bedford')
#
# ~/Documents/code_world/disc_golf/dg_fantasy/functions.py in __init__(self, name, url, year, tier, classification)
#     238             }
#     239
# --> 240             EventSearch.__init__(self, **self._search_params)
#     241
#     242         else:
#
# ~/Documents/code_world/disc_golf/dg_fantasy/functions.py in __init__(self, **kwargs)
#     155         Search.__init__(self, search_type='Event', **kwargs)
#     156
# --> 157         self._event_details = self.parser()
#     158
#     159         self.url = self._event_details[0]
#
# ~/Documents/code_world/disc_golf/dg_fantasy/functions.py in parser(self, _base_url)
#     164     def parser(self, _base_url = 'https://www.pdga.com'):
#     165
# --> 166         rows = self.parser_init()
# ...

# %%
import os
os.path
# Out:
# <module 'posixpath' from '/opt/anaconda3/envs/learn-env/lib/python3.6/posixpath.py'>

# %%
os.listdir('/Users/p.szymo/Library/Application\ Support/Google/Chrome/Default/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-96-9c70027e6b85> in <module>
# ----> 1 os.listdir('/Users/p.szymo/Library/Application\ Support/Google/Chrome/Default/')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/p.szymo/Library/Application\\ Support/Google/Chrome/Default/'

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

driver_path = '~/Users/p.szymo/Library/Application Support/Google/Chrome/Default/'
driver = webdriver.Chrome(executable_path=driver_path)
driver.get(url)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/common/service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     728                                 errread, errwrite,
# --> 729                                 restore_signals, start_new_session)
#     730         except:
#
# ...

# %%
assert "Python" in driver.title
elem = driver.find_element(By.NAME, "q")
elem.clear()
elem.send_keys("pycon")
elem.send_keys(Keys.RETURN)
assert "No results found." not in driver.page_source
driver.close()

# %%
soup.find_all("link")
# Out:
# [<link href="/apps/common/css/fontawesome.all.min.css?v=5.13.1" rel="stylesheet"/>,
#  <link href="/favicon.ico" rel="icon"/>,
#  <link href="/apps/tournament/live/js/chunk-2d0a3962.01f995e9.js" rel="prefetch"/>,
#  <link href="/apps/tournament/live/js/chunk-2d0a3ae5.b7b107d2.js" rel="prefetch"/>,
#  <link href="/apps/tournament/live/js/chunk-2d0a4d2c.4a8a4b0e.js" rel="prefetch"/>,
#  <link href="/apps/tournament/live/js/chunk-2d0af6b9.dad89905.js" rel="prefetch"/>,
#  <link href="/apps/tournament/live/js/chunk-2d0b15d8.077e0832.js" rel="prefetch"/>,
#  <link href="/apps/tournament/live/js/chunk-2d0b3a1b.35988c12.js" rel="prefetch"/>,
#  <link href="/apps/tournament/live/js/chunk-2d0b5db7.7d487ecd.js" rel="prefetch"/>,
#  <link href="/apps/tournament/live/js/chunk-2d0b97b7.bf92573b.js" rel="prefetch"/>,
#  <link href="/apps/tournament/live/js/chunk-2d0b9f2b.80e06f2f.js" rel="prefetch"/>,
#  <link href="/apps/tournament/live/js/chunk-2d0c13f7.14261402.js" rel="prefetch"/>,
# ...

# %%
soup = soupify(url)
soup
# Out:
# <!DOCTYPE html>
# <html data-vue-meta-server-rendered="" lang="en"><head><script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-6108714-1"></script><script>window.dataLayer = window.dataLayer || []
#
#     function gtag () {dataLayer.push(arguments)}
#
#     gtag('js', new Date())
#     gtag('config', 'UA-6108714-1')</script><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width,initial-scale=1" name="viewport"/><link href="/apps/common/css/fontawesome.all.min.css?v=5.13.1" rel="stylesheet"/><link href="/favicon.ico" rel="icon"/> <title>PDGA Live</title><meta content="121305337967028" name="fb:app_id">
# <meta content="Professional Disc Golf Association" name="og:site_name">
# <meta content="website" name="og:type">
# <meta content="https://www.pdga.com/apps/common/images/pdga-logo-black.svg" name="og:image"/>
# ...

# %%
len(tables)
# Out:
# 1

# %%
for i,t in enumerate(tables):
    if 'MA1' in t:
        print(i)

# %%
please break
# Out:
#   File "<ipython-input-6-bd93cd1909cb>", line 1
#     please break
#                ^
# SyntaxError: invalid syntax

# %%
players = [Player(url=link) for link in players_links]
players[:5]

# %%
roster = [
    'Simon Lizotte',
    'Alden Harris',
    'Aaron Gossage',
    'James Conrad',
    'Niklas Anttila'
]

# %%
players = [Player(player) for player in roster]
players

# %%
event_details = events_list(2023)
event_details

# %%
events = [Event(event_name, url=event_url) for event_name, event_url in event_details]
events

# %%
for player in players:
    for event in events:
        player.fantasy_score(event)

# %%
for player in players:
    player.years_results(2023)

# %%
josh = Team('Joshua Szymanowski', 'The Holy Rollers')

# %%
josh

# %%
josh.active_players

# %%
please break

# %%
event_parser_initial(mvp_open._soup)

# %%
mvp_open.__dict__.keys()

# %%
mvp_open.results_df.head()

# %%
mvp_open.save_event_results('csv_results/')

# %%
event_url, event_official_name = event_parser('a', 'https://www.pdga.com/tour/search?OfficialName=mvp%20open&date_filter[min][date]=2023-01-01&date_filter[max][date]=2023-12-31')
event_url, event_official_name

# %%
pro_events[0].select('a[href*="/tour/event/"]')[0]['href']

# %%
pro_events[0].__dict__

# %%
pro_events[0].select('a[href*="https://www.pdga.com/tour/event/"]')

# %%
odd_rows

# %%
class Event:
    
    def __init__(self, name, year):
        self.name = name.strip()
        self.year = int(year)
        
        self._base_url = 'https://www.pdga.com/tour/search'
        self._event_name = self.name.replace(' ','%20')
        self._min_date = f'{self.year}-01-01'
        self._max_date = f'{self.year}-12-31'
        self.search_url = f'{self._base_url}?OfficialName={self._event_name}&date_filter[min][date]={self._min_date}&date_filter[max][date]={self._max_date}
        
        soup = soupify(self.search_url)
        
        self.event_number = 
        self.event_url = 
        '

# %%
players[0].__dict__

# %%
events_url = 'https://www.pdga.com/elite-series'

events = events_list(events_url)

events += [
    ('Portland Open', 'https://www.pdga.com/tour/event/69022'),
    ('Des Moines Challenge', 'https://www.pdga.com/tour/event/67392'),
    ('The Preserve Championship', 'https://www.pdga.com/tour/event/68353'),
    ('PCS Open', 'https://www.pdga.com/tour/event/64036'),
    ('USDGC', 'https://www.pdga.com/tour/event/64957')
]

for event in events:
    print(f'{event[0]} : {event[1]}')

# %%
results = {
    event[0]: results(
        event[0], event[1], save_df=False # save_df=True
    ) for event in events
}

# %%
total_results_by_players = total_scorer(results, roster)

# %%
print_output(total_results_by_players)
